# %% [markdown]
# # K- Nearest Neighbour

# %%
import pandas as pd
from pandas import Series,DataFrame
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from sklearn.model_selection import GridSearchCV
import numpy as np

# %%
# I have Used the  prostate cancer  dataset
data = pd.read_csv("C:\\Users\\Hp\\Downloads\\Prostate-cancer-prediction-master\\Prostate-cancer-prediction-master\\Prostate_Cancer.csv",index_col=0)

# %%
data
# Out:
#     diagnosis_result  radius  texture  perimeter  area  smoothness  \
# id
# 1                  M      23       12        151   954       0.143
# 2                  B       9       13        133  1326       0.143
# 3                  M      21       27        130  1203       0.125
# 4                  M      14       16         78   386       0.070
# 5                  M       9       19        135  1297       0.141
# ..               ...     ...      ...        ...   ...         ...
# 96                 M      23       16        132  1264       0.091
# 97                 B      22       14         78   451       0.105
# 98                 B      19       27         62   295       0.102
# 99                 B      21       24         74   413       0.090
# 100                M      16       27         94   643       0.098
#
#      compactness  symmetry  fractal_dimension
# id
# 1          0.278     0.242              0.079
# 2          0.079     0.181              0.057
# ...

# %%
data.head()
# Out:
#    diagnosis_result  radius  texture  perimeter  area  smoothness  \
# id
# 1                 M      23       12        151   954       0.143
# 2                 B       9       13        133  1326       0.143
# 3                 M      21       27        130  1203       0.125
# 4                 M      14       16         78   386       0.070
# 5                 M       9       19        135  1297       0.141
#
#     compactness  symmetry  fractal_dimension
# id
# 1         0.278     0.242              0.079
# 2         0.079     0.181              0.057
# 3         0.160     0.207              0.060
# 4         0.284     0.260              0.097
# 5         0.133     0.181              0.059

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 100 entries, 1 to 100
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   diagnosis_result   100 non-null    object
#  1   radius             100 non-null    int64
#  2   texture            100 non-null    int64
#  3   perimeter          100 non-null    int64
#  4   area               100 non-null    int64
#  5   smoothness         100 non-null    float64
#  6   compactness        100 non-null    float64
#  7   symmetry           100 non-null    float64
#  8   fractal_dimension  100 non-null    float64
# dtypes: float64(4), int64(4), object(1)
# memory usage: 7.8+ KB

# %% [markdown]
# Since the diagnosis_result column is in text , we need to convert it to binary so that it can be fed into the algorithm.

# %%
df=data

# %%
#using StandardScaler
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
scaler.fit(df.drop('diagnosis_result',axis=1))
#removing the last column of the dataframe as this table will be used for the feature matrix
scaled_features=scaler.transform(df.drop('diagnosis_result',axis=1))
new_data=pd.DataFrame(scaled_features,columns=df.columns[:-1])

# %%
data.head()
# Out:
#    diagnosis_result  radius  texture  perimeter  area  smoothness  \
# id
# 1                 M      23       12        151   954       0.143
# 2                 B       9       13        133  1326       0.143
# 3                 M      21       27        130  1203       0.125
# 4                 M      14       16         78   386       0.070
# 5                 M       9       19        135  1297       0.141
#
#     compactness  symmetry  fractal_dimension
# id
# 1         0.278     0.242              0.079
# 2         0.079     0.181              0.057
# 3         0.160     0.207              0.060
# 4         0.284     0.260              0.097
# 5         0.133     0.181              0.059

# %%
#feature matrix
X = df.drop(columns=['diagnosis_result'])

# %%
#target matrix
y=df['diagnosis_result']

# %%
# Importing the train_test_split function from the scikit-learn library
from sklearn.model_selection import train_test_split

# %%
# Split the dataset into training and testing sets, with 80% of the data used for training and 20% for testing
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
# random value of n_neighbors, we will find a better value of k later.
knn = KNeighborsClassifier(n_neighbors=5)

# %%
knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
# Use the trained KNN model to make predictions on the test data
pred=knn.predict(X_test)

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
from sklearn.metrics import accuracy_score

# %%
# Calculate the accuracy of the model by comparing the true labels (y_test) with the predicted labels (y_pred)
accuracy = accuracy_score(y_test, pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.8

# %%
# Generated and print a classification report comparing the true labels (y_test) with the predicted labels (pred)
print(classification_report(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#            B       0.70      0.88      0.78         8
#            M       0.90      0.75      0.82        12
#
#     accuracy                           0.80        20
#    macro avg       0.80      0.81      0.80        20
# weighted avg       0.82      0.80      0.80        20
